# %% [markdown]
# # Subquestion weather data
#
# This file will explain the subquesion: *Which specific weather conditions most significantly impact flight delays on the JFK-LAX route?*
#
# This file explains how we used the data step by step. We used two datasets to answer this question: one with weather data in JFK and one with weather data in LAX.

# %%
import pandas as pd
import numpy as np

weather_LAX = pd.read_csv('LAX.csv')
weather_JFK = pd.read_csv('JFK (1).csv')

display(weather_JFK.head())
display(weather_LAX.head())
# Out:
#   station             valid  tmpf  dwpf   relh   drct  sknt  p01i   alti  \
# 0     JFK  2013-01-01 00:51  38.0  23.0  54.51  240.0  14.0  0.00  29.96
# 1     JFK  2013-01-01 01:51  38.0  24.0  57.04  250.0  15.0  0.00  29.93
# 2     JFK  2013-01-01 02:51  39.0  25.0  56.77  240.0  17.0  0.00  29.92
# 3     JFK  2013-01-01 03:51  39.0  26.0  59.37  240.0  16.0  0.00  29.92
# 4     JFK  2013-01-01 04:51  39.0  25.0  56.77  260.0  13.0  0.00  29.92
#
#      mslp  ...  wxcodes  ice_accretion_1hr ice_accretion_3hr  \
# 0  1014.4  ...      NaN                NaN               NaN
# 1  1013.5  ...      NaN                NaN               NaN
# 2  1013.0  ...      NaN                NaN               NaN
# 3  1013.2  ...      NaN                NaN               NaN
# 4  1013.2  ...      NaN                NaN               NaN
#
#   ice_accretion_6hr peak_wind_gust peak_wind_drct  peak_wind_time   feel  \
# 0               NaN            NaN            NaN             NaN  28.82
# ...

# %% [markdown]
# We modified the table to use only the parameters with the most impact on flights. We use the following parameters:
# - Wind Gust
# - Wind Speed
# - Precipitation
# - Visability
# - Sky coverage
#
# ![image.png](attachment:image.png)
#
#
# We modified this table to get the graphs. Furthermore, we have filtered the NaN and removed this value from the dataset. For precipitation the number 'T' means almost zero. We have modified sky level coverage 1,2,3 and 4 to six different stages of coverage:
# - CLR: 1, Clear
# - FEW: 2, Few
# - SCT: 3, Scattered
# - BKN: 4, Broken
# - OVC: 5, Overcast
# - VV:  6, Vertical Visibility
#
#
# For each of these paramters we have data for each month. We have plotted each variable during the month, to get a nice overview of the behaviour of these parameters. All the plots can be found in the map of this subquestion, with the name of the notebook: Modify_JFK_weather. For now, we only show the january plots and discuss the striking values. Below are the parameters of JFK for january:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
# ![image-9.png](attachment:image-9.png)
# ![image-10.png](attachment:image-10.png)

# %% [markdown]
# For each of these parameters we have data for each month for LAX as well. We have plotted each parameter during the month, to get a nice overview of the behaviour of these parameters. All the plots can be found in the map of this subquestion, with the name of the notebook: Modify_LAX_weather. For now, we only show the january plots and discuss the striking values. Below are the parameters of LAX for january:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
# ![image-9.png](attachment:image-9.png)
# ![image-10.png](attachment:image-10.png)

# %% [markdown]
# Now we have seen the plots of the different variables, we can discuss the remarkable values.  We can see different values for LAX and JFK for each parameter. This means that the weather or climate is different in each city.
#
# In Los Angeles, we observe several anomalies and patterns in the weather data:
# - Wind Speed at LAX: There is an outlier recorded in January, showing a wind speed of 800 km/h, which is likely a data fault or error.
# - Wind Gusts: Wind gust data is often sparse, and in many cases, no wind gusts are recorded.
# - Pressure altimeter: this data fluctures fluctures around 30 inches.
# - Visibility: During January and February, visibility consistently measures 10 kilometers, with no significant variation.
# - Precipitation: Precipitation levels are nearly always zero, indicating minimal rainfall throughout this period.
# - Sky Coverage: The higher the sky level coverage, the fewer data points available, suggesting that higher altitudes may be more challenging to measure accurately.
#
# At JFK, we observe the following weather data patterns:
# - Wind Gusts: There are significantly more data points for wind gusts compared to LAX, indicating more frequent gusty conditions at JFK.
# - Pressure Altimeter: The pressure fluctuates around 30 inches, showing regular variability.
# - Visibility: For about 80% of the month, visibility is recorded as 10 kilometers, indicating generally clear conditions.
# - Precipitation & Sky Level Coverage: These patterns are similar to those observed at LAX
# - Sky Coverage: Similar to LAX, higher sky levels have fewer data points, possibly due to measurement challenges. However, JFK experiences more cloud cover than LAX.
#
# Now we know how this weather data looks, we can use this data to compare the weather data to the delays.
