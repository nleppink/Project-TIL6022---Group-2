# %% [markdown]
# # Sub Question 3
# ## What is the relationship between the chosen weather patterns and the duration and occurence of flight delays upon departure and arrival?
# *TIL6022 - Pyhton Programming*
#
# **A stormy flight: Investigating the correlation between weather patterns and delays on the JFK-LAX route**
#
#
# Members: Nynke Leppink, Alexander du Marchie Sarvaas, Samuel du Marchie Sarvaas, Sanne van Proosdij, Emma Toet
#
# Student numbers: 5070988, 5547156, 4802829, 5326990, 4849892

# %% [markdown]
# This chapter addresses the third sub-question: *"What is the relationship between the selected weather patterns and the duration and occurrence of flight delays upon departure and arrival?"*. The sub-question is answered by plotting the correlation between flight delays and individual weather variables to identify any patterns. These graphs are then analyzed by examining the data points and plotting a regression line to identify trends. This analysis is conducted for departure delays at JFK Airport in New York using weather data from the same airport, and for arrival delays at LAX Airport in Los Angeles using corresponding weather data from LAX.
#
# First, the datasets are merged, linking weather variables to the respective flights. The departure and arrival times of the flights are adjusted to align with the hourly intervals of the weather data. This allows the correct weather variables for a specific hour to be matched with each flight. The merged datasets are represented in the CSV files *Arrival_weather_combined.csv* and *Departures_weather_combined.csv*.
#
# Additionally, based on the insights from sub-question 1, the arrival delay has been adjusted to reflect the actual arrival delay, by subtracting the departure delay from the initial reported arrival delay.
#
# The top rows of the two datasets are displayed below:

# %%
#displays the departure flights from JFK Airport in New York merged with the weather data from JFK Airport
import pandas as pd
pd.read_csv('Departures_weather_combined.csv').head()
# Out:
#    Unnamed: 0 sched_dep_datetime (mod) dep_time sched_dep_time  dep_delay  \
# 0           0      2013-01-01 05:51:00    05:58          06:00       -2.0
# 1           1      2013-01-01 06:51:00    06:58          07:00       -2.0
# 2           2      2013-01-01 06:51:00    07:02          07:00        2.0
# 3           3      2013-01-01 07:51:00    07:43          07:30       13.0
# 4           4      2013-01-01 08:51:00    08:29          08:30       -1.0
#
#                      name  actual_delay station  Wind Speed [in knots]  \
# 0   United Air Lines Inc.           5.0     JFK                   11.0
# 1          Virgin America           0.0     JFK                   11.0
# 2         JetBlue Airways          46.0     JFK                   11.0
# 3  American Airlines Inc.          20.0     JFK                   10.0
# 4   United Air Lines Inc.          -9.0     JFK                   13.0
#
#    Wind Gust [in knots] One hour precipitation [in inches]  \
# 0                   NaN                               0.00
# 1                   NaN                               0.00
# 2                   NaN                               0.00
# 3                   NaN                               0.00
# 4                   NaN                               0.00
#
#    Pressure altimeter [in inches]  Visibility [in miles]  \
# 0                           29.89                   10.0
# 1                           29.90                   10.0
# 2                           29.90                   10.0
# 3                           29.90                   10.0
# 4                           29.91                   10.0
#
#    Sky Level 1 Coverage  Sky Level 2 Coverage  Sky Level 3 Coverage  \
# 0                   5.0                   NaN                   NaN
# 1                   5.0                   NaN                   NaN
# 2                   5.0                   NaN                   NaN
# 3                   4.0                   4.0                   5.0
# 4                   5.0                   NaN                   NaN
#
#    Sky Level 4 Coverage
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
#displays the arrival flights from LAX Airport in Los Angeles merged with the weather data from LAX Airport
pd.read_csv('Arrival_weather_combined.csv').head()
# Out:
#    Unnamed: 0 sched_arr_datetime (mod) arr_time sched_arr_time  arr_delay  \
# 0           0      2013-01-01 08:53:00    09:24          09:17        7.0
# 1           1      2013-01-01 10:53:00    10:27          10:25        2.0
# 2           2      2013-01-01 09:53:00    10:58          10:14       44.0
# 3           3      2013-01-01 10:53:00    11:07          11:00        7.0
# 4           4      2013-01-01 11:53:00    11:52          12:00       -8.0
#
#                      name  actual_delay station  Wind Speed [in knots]  \
# 0   United Air Lines Inc.           5.0     LAX                    4.0
# 1          Virgin America           0.0     LAX                    5.0
# 2         JetBlue Airways          46.0     LAX                    4.0
# 3  American Airlines Inc.          20.0     LAX                    5.0
# 4   United Air Lines Inc.          -9.0     LAX                    3.0
#
#    Wind Gust [in knots] One hour precipitation [in inches]  \
# 0                   NaN                               0.00
# 1                   NaN                               0.00
# 2                   NaN                               0.00
# 3                   NaN                               0.00
# 4                   NaN                               0.00
#
#    Pressure altimeter [in inches]  Visibility [in miles]  \
# 0                           30.23                   10.0
# 1                           30.24                   10.0
# 2                           30.25                   10.0
# 3                           30.24                   10.0
# 4                           30.21                   10.0
#
#    Sky Level 1 Coverage  Sky Level 2 Coverage  Sky Level 3 Coverage  \
# 0                   4.0                   NaN                   NaN
# 1                   4.0                   NaN                   NaN
# 2                   3.0                   NaN                   NaN
# 3                   4.0                   NaN                   NaN
# 4                   4.0                   NaN                   NaN
#
#    Sky Level 4 Coverage
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %% [markdown]
# This report examines the relationship between severe weather patterns and the duration and occurrence of flight delays. Notably, flights without delays are not excluded from the analysis. This is important because some flights may experience severe weather but still arrive or departure on time, and excluding them could cause biassed results. By including all flights, regardless of delay status, the analysis aims to determine whether a correlation exists between weather conditions and delays.
#
# For example, as shown in the figure titled "Correlation between Precipitation and Departure Delays at JFK," extreme precipitation does not consistently result in significant delays. Several other plots display similar relationships, with the y-axis representing flight delays and the x-axis showing various weather conditions.
#
# Despite plotting these relationships, the figures indicate no clear correlation between weather patterns and flight delays. A regression line has been included in the plots to highlight any potential trends, but it confirms the lack of a strong relationship.
# As a result, the next step in the analysis will explore whether combining different weather variables might reveal any trends, which could provide more insight into how weather impacts flight delays.
#
#
# **Departure flights**

# %% [markdown]
# <table>
#     <tr>
#         <td><img src="attachment:image.png" alt="Image 1" style="max-width: 100%;"/></td>
#         <td><img src="attachment:image-2.png" alt="Image 2" style="max-width: 100%;"/></td>
#         <td><img src="attachment:image-3.png" alt="Image 3" style="max-width: 100%;"/></td>
#     </tr>
#     <tr>
#         <td><img src="attachment:image-4.png" alt="Image 4" style="max-width: 100%;"/></td>
#         <td><img src="attachment:image-5.png" alt="Image 5" style="max-width: 100%;"/></td>
#         <td><img src="attachment:image-6.png" alt="Image 6" style="max-width: 100%;"/></td>
#     </tr>
#     <tr>
#         <td><img src="attachment:image-7.png" alt="Image 7" style="max-width: 100%;"/></td>
#         <td><img src="attachment:image-8.png" alt="Image 8" style="max-width: 100%;"/></td>
#         <td><img src="attachment:image-9.png" alt="Image 9" style="max-width: 100%;"/></td>
#     </tr>
# </table>

# %% [markdown]
# **Arrival flights**

# %% [markdown]
# <table>
#     <tr>
#         <td><img src="attachment:image.png" alt="Image 1" style="max-width: 100%;"/></td>
#         <td><img src="attachment:image-2.png" alt="Image 2" style="max-width: 100%;"/></td>
#         <td><img src="attachment:image-3.png" alt="Image 3" style="max-width: 100%;"/></td>
#     </tr>
#     <tr>
#         <td><img src="attachment:image-4.png" alt="Image 4" style="max-width: 100%;"/></td>
#         <td><img src="attachment:image-5.png" alt="Image 5" style="max-width: 100%;"/></td>
#         <td><img src="attachment:image-6.png" alt="Image 6" style="max-width: 100%;"/></td>
#     </tr>
#     <tr>
#         <td><img src="attachment:image-7.png" alt="Image 7" style="max-width: 100%;"/></td>
#         <td><img src="attachment:image-8.png" alt="Image 8" style="max-width: 100%;"/></td>
#         <td><img src="attachment:image-9.png" alt="Image 9" style="max-width: 100%;"/></td>
#     </tr>
# </table>
